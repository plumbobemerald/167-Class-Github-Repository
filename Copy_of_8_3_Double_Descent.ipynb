# %% [markdown]
# <a href="https://colab.research.google.com/github/plumbobemerald/167-Class-Github-Repository/blob/main/Copy_of_8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-9alrpgoi
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-9alrpgoi
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=b27dd01a8c976da5bf65aea88bea838cbcd708ba26bcbb5b9b6afac7f3766bda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fb0gybry/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
#
# Around 45–60 hidden units (that’s where total params ≈ number of training examples, so the net can memorize).
#
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
#
# Roughly 20–35 hidden units (the usual bias–variance sweet spot before interpolation).
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
#
# Near the interpolation threshold, about 40–50 hidden units (where params ≈ 4,000).

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.306074, train error 89.75,  test loss 2.307479, test error 90.57
# Epoch   100, train loss 2.289499, train error 89.28,  test loss 2.303056, test error 89.93
# Epoch   200, train loss 2.268119, train error 88.82,  test loss 2.281789, test error 89.15
# Epoch   300, train loss 2.027156, train error 77.10,  test loss 1.941370, test error 76.28
# Epoch   400, train loss 1.897476, train error 71.97,  test loss 1.738385, test error 69.80
# Epoch   500, train loss 1.880922, train error 71.93,  test loss 1.725775, test error 67.88
# Epoch   600, train loss 1.870081, train error 72.07,  test loss 1.717290, test error 68.35
# Epoch   700, train loss 1.864067, train error 71.07,  test loss 1.707603, test error 68.07
# Epoch   800, train loss 1.864206, train error 71.82,  test loss 1.713206, test error 68.05
# Epoch   900, train loss 1.864204, train error 71.25,  test loss 1.711580, test error 67.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.302083, train error 89.38,  test loss 2.300313, test error 88.75
# Epoch   100, train loss 1.783298, train error 66.00,  test loss 1.632882, test error 64.07
# Epoch   200, train loss 1.771745, train error 65.10,  test loss 1.621852, test error 63.97
# Epoch   300, train loss 1.763169, train error 64.32,  test loss 1.619923, test error 63.67
# Epoch   400, train loss 1.762046, train error 64.70,  test loss 1.630312, test error 64.22
# Epoch   500, train loss 1.754972, train error 64.47,  test loss 1.624222, test error 64.03
# Epoch   600, train loss 1.754485, train error 64.43,  test loss 1.625134, test error 63.83
# Epoch   700, train loss 1.750512, train error 64.28,  test loss 1.631284, test error 64.32
# Epoch   800, train loss 1.749657, train error 64.53,  test loss 1.628287, test error 64.53
# Epoch   900, train loss 1.749105, train error 64.43,  test loss 1.635223, test error 63.83
# Training model with   6 hidden variables
# Epoch     0, train loss 2.305532, train error 90.22,  test loss 2.306971, test error 90.62
# Epoch   100, train loss 1.663925, train error 60.05,  test loss 1.507718, test error 57.88
# Epoch   200, train loss 1.642869, train error 59.22,  test loss 1.498362, test error 57.92
# Epoch   300, train loss 1.632220, train error 59.20,  test loss 1.509986, test error 57.78
# Epoch   400, train loss 1.622829, train error 58.97,  test loss 1.499940, test error 58.17
# Epoch   500, train loss 1.619283, train error 58.95,  test loss 1.498476, test error 57.80
# Epoch   600, train loss 1.619594, train error 58.47,  test loss 1.510683, test error 57.72
# Epoch   700, train loss 1.614380, train error 57.88,  test loss 1.501071, test error 57.38
# Epoch   800, train loss 1.614684, train error 58.42,  test loss 1.512618, test error 58.12
# Epoch   900, train loss 1.616507, train error 58.83,  test loss 1.515155, test error 58.92
# Training model with   8 hidden variables
# Epoch     0, train loss 2.270493, train error 85.90,  test loss 2.283535, test error 87.43
# Epoch   100, train loss 1.616603, train error 58.05,  test loss 1.441427, test error 55.75
# Epoch   200, train loss 1.566801, train error 55.55,  test loss 1.428992, test error 55.83
# Epoch   300, train loss 1.544331, train error 54.95,  test loss 1.427783, test error 55.22
# Epoch   400, train loss 1.541566, train error 54.80,  test loss 1.443212, test error 55.28
# Epoch   500, train loss 1.533647, train error 54.42,  test loss 1.435373, test error 54.97
# Epoch   600, train loss 1.529887, train error 54.88,  test loss 1.446211, test error 55.65
# Epoch   700, train loss 1.526722, train error 54.58,  test loss 1.455792, test error 55.83
# Epoch   800, train loss 1.523211, train error 54.45,  test loss 1.445414, test error 55.50
# Epoch   900, train loss 1.522130, train error 54.60,  test loss 1.458495, test error 55.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.221832, train error 81.30,  test loss 2.192735, test error 80.75
# Epoch   100, train loss 1.521123, train error 52.88,  test loss 1.360852, test error 51.00
# Epoch   200, train loss 1.437840, train error 49.62,  test loss 1.292915, test error 48.08
# Epoch   300, train loss 1.418008, train error 48.97,  test loss 1.293695, test error 48.22
# Epoch   400, train loss 1.405973, train error 47.67,  test loss 1.298892, test error 48.30
# Epoch   500, train loss 1.396988, train error 48.17,  test loss 1.305605, test error 49.12
# Epoch   600, train loss 1.388542, train error 47.08,  test loss 1.315920, test error 48.97
# Epoch   700, train loss 1.388598, train error 47.58,  test loss 1.326075, test error 49.35
# Epoch   800, train loss 1.388928, train error 47.15,  test loss 1.335379, test error 49.80
# Epoch   900, train loss 1.381733, train error 46.78,  test loss 1.328339, test error 49.12
# Training model with  14 hidden variables
# Epoch     0, train loss 2.263542, train error 85.10,  test loss 2.262648, test error 86.35
# Epoch   100, train loss 1.468996, train error 50.45,  test loss 1.393800, test error 53.47
# Epoch   200, train loss 1.388691, train error 48.40,  test loss 1.359620, test error 51.78
# Epoch   300, train loss 1.350481, train error 46.65,  test loss 1.356745, test error 50.75
# Epoch   400, train loss 1.330809, train error 45.38,  test loss 1.360925, test error 50.17
# Epoch   500, train loss 1.312579, train error 44.97,  test loss 1.390857, test error 50.97
# Epoch   600, train loss 1.298059, train error 44.53,  test loss 1.390911, test error 51.00
# Epoch   700, train loss 1.301322, train error 44.40,  test loss 1.415877, test error 51.47
# Epoch   800, train loss 1.281495, train error 43.72,  test loss 1.413213, test error 51.58
# Epoch   900, train loss 1.284431, train error 44.30,  test loss 1.443277, test error 52.17
# Training model with  18 hidden variables
# Epoch     0, train loss 2.273868, train error 85.60,  test loss 2.276051, test error 85.62
# Epoch   100, train loss 1.345755, train error 46.28,  test loss 1.324052, test error 50.62
# Epoch   200, train loss 1.240239, train error 41.88,  test loss 1.340635, test error 48.85
# Epoch   300, train loss 1.199514, train error 40.97,  test loss 1.393151, test error 48.97
# Epoch   400, train loss 1.179029, train error 39.85,  test loss 1.436911, test error 49.80
# Epoch   500, train loss 1.167363, train error 40.00,  test loss 1.467195, test error 49.80
# Epoch   600, train loss 1.151743, train error 38.88,  test loss 1.490919, test error 50.47
# Epoch   700, train loss 1.148616, train error 38.90,  test loss 1.513583, test error 51.08
# Epoch   800, train loss 1.133530, train error 38.33,  test loss 1.518935, test error 51.03
# Epoch   900, train loss 1.137409, train error 38.22,  test loss 1.551694, test error 51.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.135428, train error 80.25,  test loss 2.085588, test error 78.93
# Epoch   100, train loss 1.277732, train error 42.60,  test loss 1.341846, test error 50.25
# Epoch   200, train loss 1.138121, train error 37.35,  test loss 1.428471, test error 50.78
# Epoch   300, train loss 1.081817, train error 35.65,  test loss 1.489262, test error 51.25
# Epoch   400, train loss 1.046868, train error 34.82,  test loss 1.529511, test error 51.53
# Epoch   500, train loss 1.023118, train error 34.03,  test loss 1.607543, test error 52.20
# Epoch   600, train loss 1.011886, train error 34.18,  test loss 1.656869, test error 52.85
# Epoch   700, train loss 0.992615, train error 33.40,  test loss 1.728225, test error 52.92
# Epoch   800, train loss 0.990538, train error 33.82,  test loss 1.803743, test error 54.60
# Epoch   900, train loss 0.967698, train error 33.38,  test loss 1.793223, test error 53.38
# Training model with  26 hidden variables
# Epoch     0, train loss 2.127660, train error 78.68,  test loss 2.094245, test error 77.47
# Epoch   100, train loss 1.178475, train error 39.10,  test loss 1.325884, test error 49.12
# Epoch   200, train loss 1.047147, train error 34.97,  test loss 1.404487, test error 49.65
# Epoch   300, train loss 0.982968, train error 32.65,  test loss 1.529815, test error 51.17
# Epoch   400, train loss 0.940602, train error 31.25,  test loss 1.609840, test error 51.38
# Epoch   500, train loss 0.897023, train error 31.05,  test loss 1.743144, test error 53.20
# Epoch   600, train loss 0.885501, train error 30.28,  test loss 1.844499, test error 52.65
# Epoch   700, train loss 0.863600, train error 29.82,  test loss 1.926848, test error 54.17
# Epoch   800, train loss 0.842333, train error 29.50,  test loss 1.995810, test error 53.47
# Epoch   900, train loss 0.831856, train error 28.62,  test loss 2.072237, test error 53.67
# Training model with  30 hidden variables
# Epoch     0, train loss 2.161227, train error 79.45,  test loss 2.126312, test error 78.72
# Epoch   100, train loss 1.112565, train error 36.15,  test loss 1.315849, test error 48.10
# Epoch   200, train loss 0.929282, train error 31.97,  test loss 1.451929, test error 48.88
# Epoch   300, train loss 0.860050, train error 28.60,  test loss 1.630183, test error 50.92
# Epoch   400, train loss 0.815103, train error 27.75,  test loss 1.775239, test error 50.92
# Epoch   500, train loss 0.789748, train error 27.22,  test loss 1.992417, test error 52.85
# Epoch   600, train loss 0.730818, train error 24.75,  test loss 2.103957, test error 51.88
# Epoch   700, train loss 0.720833, train error 24.85,  test loss 2.260789, test error 53.05
# Epoch   800, train loss 0.688641, train error 22.97,  test loss 2.421798, test error 52.90
# Epoch   900, train loss 0.673881, train error 23.05,  test loss 2.541118, test error 53.15
# Training model with  35 hidden variables
# Epoch     0, train loss 2.117008, train error 78.12,  test loss 2.095599, test error 78.25
# Epoch   100, train loss 0.998401, train error 32.00,  test loss 1.401332, test error 48.85
# Epoch   200, train loss 0.765252, train error 25.62,  test loss 1.719840, test error 51.33
# Epoch   300, train loss 0.682260, train error 23.45,  test loss 2.155779, test error 53.62
# Epoch   400, train loss 0.599830, train error 20.28,  test loss 2.517615, test error 55.65
# Epoch   500, train loss 0.575725, train error 20.22,  test loss 2.820016, test error 56.38
# Epoch   600, train loss 0.507290, train error 17.47,  test loss 3.170945, test error 56.03
# Epoch   700, train loss 0.443407, train error 15.12,  test loss 3.532346, test error 56.30
# Epoch   800, train loss 0.437016, train error 15.80,  test loss 3.907489, test error 56.70
# Epoch   900, train loss 0.422198, train error 14.90,  test loss 4.322226, test error 57.42
# Training model with  40 hidden variables
# Epoch     0, train loss 2.112043, train error 78.88,  test loss 2.084105, test error 79.45
# Epoch   100, train loss 0.928674, train error 30.62,  test loss 1.458484, test error 49.85
# Epoch   200, train loss 0.648781, train error 20.35,  test loss 1.931816, test error 52.50
# Epoch   300, train loss 0.513926, train error 16.57,  test loss 2.470975, test error 55.33
# Epoch   400, train loss 0.444081, train error 14.88,  test loss 3.064100, test error 56.03
# Epoch   500, train loss 0.378845, train error 12.45,  test loss 3.695542, test error 56.58
# Epoch   600, train loss 0.330058, train error 11.00,  test loss 4.404481, test error 56.92
# Epoch   700, train loss 0.345499, train error 12.95,  test loss 5.044040, test error 58.12
# Epoch   800, train loss 0.266943, train error 9.07,  test loss 5.636021, test error 57.55
# Epoch   900, train loss 0.224783, train error 7.72,  test loss 6.217130, test error 58.25
# Training model with  45 hidden variables
# Epoch     0, train loss 2.121431, train error 78.07,  test loss 2.092238, test error 77.75
# Epoch   100, train loss 0.828164, train error 25.62,  test loss 1.525055, test error 50.17
# Epoch   200, train loss 0.498857, train error 15.53,  test loss 2.192434, test error 51.83
# Epoch   300, train loss 0.334568, train error 10.25,  test loss 3.179689, test error 53.35
# Epoch   400, train loss 0.279187, train error 9.70,  test loss 4.446593, test error 55.22
# Epoch   500, train loss 0.209194, train error 7.35,  test loss 5.501088, test error 55.08
# Epoch   600, train loss 0.201674, train error 7.18,  test loss 6.596735, test error 55.75
# Epoch   700, train loss 0.244215, train error 7.97,  test loss 7.890263, test error 56.95
# Epoch   800, train loss 0.156017, train error 5.15,  test loss 8.469568, test error 54.88
# Epoch   900, train loss 0.220752, train error 7.47,  test loss 9.552076, test error 55.58
# Training model with  50 hidden variables
# Epoch     0, train loss 2.092985, train error 77.78,  test loss 2.053232, test error 78.03
# Epoch   100, train loss 0.744617, train error 22.78,  test loss 1.550047, test error 49.92
# Epoch   200, train loss 0.347684, train error 10.25,  test loss 2.533563, test error 52.40
# Epoch   300, train loss 0.146936, train error 3.47,  test loss 4.098328, test error 54.20
# Epoch   400, train loss 0.028048, train error 0.00,  test loss 5.678662, test error 55.10
# Epoch   500, train loss 0.013103, train error 0.00,  test loss 6.609219, test error 55.00
# Epoch   600, train loss 0.008379, train error 0.00,  test loss 7.228829, test error 55.08
# Epoch   700, train loss 0.005863, train error 0.00,  test loss 7.681730, test error 55.03
# Epoch   800, train loss 0.004554, train error 0.00,  test loss 8.055266, test error 55.00
# Epoch   900, train loss 0.003662, train error 0.00,  test loss 8.358245, test error 55.15
# Training model with  55 hidden variables
# Epoch     0, train loss 2.033789, train error 75.12,  test loss 1.958729, test error 74.78
# Epoch   100, train loss 0.628698, train error 18.82,  test loss 1.652515, test error 50.35
# Epoch   200, train loss 0.227899, train error 5.20,  test loss 2.919070, test error 53.00
# Epoch   300, train loss 0.040794, train error 0.03,  test loss 4.603354, test error 54.65
# Epoch   400, train loss 0.014431, train error 0.00,  test loss 5.609285, test error 54.85
# Epoch   500, train loss 0.008442, train error 0.00,  test loss 6.227588, test error 54.80
# Epoch   600, train loss 0.005859, train error 0.00,  test loss 6.665237, test error 55.03
# Epoch   700, train loss 0.004392, train error 0.00,  test loss 7.011236, test error 55.08
# Epoch   800, train loss 0.003444, train error 0.00,  test loss 7.288517, test error 55.03
# Epoch   900, train loss 0.002844, train error 0.00,  test loss 7.527070, test error 54.88
# Training model with  60 hidden variables
# Epoch     0, train loss 2.090621, train error 77.22,  test loss 2.049119, test error 76.45
# Epoch   100, train loss 0.544829, train error 15.55,  test loss 1.743904, test error 51.47
# Epoch   200, train loss 0.138416, train error 2.72,  test loss 3.362406, test error 54.83
# Epoch   300, train loss 0.022159, train error 0.00,  test loss 4.833581, test error 54.75
# Epoch   400, train loss 0.010150, train error 0.00,  test loss 5.574568, test error 54.97
# Epoch   500, train loss 0.006379, train error 0.00,  test loss 6.058525, test error 55.08
# Epoch   600, train loss 0.004497, train error 0.00,  test loss 6.409460, test error 55.12
# Epoch   700, train loss 0.003447, train error 0.00,  test loss 6.689855, test error 55.28
# Epoch   800, train loss 0.002762, train error 0.00,  test loss 6.922101, test error 55.33
# Epoch   900, train loss 0.002300, train error 0.00,  test loss 7.123256, test error 55.42
# Training model with  70 hidden variables
# Epoch     0, train loss 2.029199, train error 75.30,  test loss 1.945929, test error 74.10
# Epoch   100, train loss 0.382578, train error 9.53,  test loss 1.932370, test error 52.72
# Epoch   200, train loss 0.035160, train error 0.00,  test loss 3.666264, test error 54.33
# Epoch   300, train loss 0.011277, train error 0.00,  test loss 4.501378, test error 54.65
# Epoch   400, train loss 0.006180, train error 0.00,  test loss 4.966596, test error 54.65
# Epoch   500, train loss 0.004135, train error 0.00,  test loss 5.279157, test error 54.72
# Epoch   600, train loss 0.003053, train error 0.00,  test loss 5.520923, test error 54.83
# Epoch   700, train loss 0.002390, train error 0.00,  test loss 5.714205, test error 54.88
# Epoch   800, train loss 0.001951, train error 0.00,  test loss 5.875567, test error 54.83
# Epoch   900, train loss 0.001638, train error 0.00,  test loss 6.016005, test error 55.00
# Training model with  80 hidden variables
# Epoch     0, train loss 2.033469, train error 75.10,  test loss 1.990541, test error 76.43
# Epoch   100, train loss 0.227297, train error 3.40,  test loss 2.000944, test error 50.62
# Epoch   200, train loss 0.020968, train error 0.00,  test loss 3.338480, test error 51.60
# Epoch   300, train loss 0.008249, train error 0.00,  test loss 3.888039, test error 52.00
# Epoch   400, train loss 0.004873, train error 0.00,  test loss 4.220281, test error 52.08
# Epoch   500, train loss 0.003358, train error 0.00,  test loss 4.454778, test error 51.85
# Epoch   600, train loss 0.002515, train error 0.00,  test loss 4.632907, test error 51.85
# Epoch   700, train loss 0.001995, train error 0.00,  test loss 4.780703, test error 52.03
# Epoch   800, train loss 0.001641, train error 0.00,  test loss 4.905143, test error 52.00
# Epoch   900, train loss 0.001388, train error 0.00,  test loss 5.012207, test error 51.95
# Training model with  90 hidden variables
# Epoch     0, train loss 2.021018, train error 74.65,  test loss 1.967067, test error 74.88
# Epoch   100, train loss 0.142615, train error 1.35,  test loss 2.215247, test error 52.20
# Epoch   200, train loss 0.014988, train error 0.00,  test loss 3.318529, test error 53.25
# Epoch   300, train loss 0.006672, train error 0.00,  test loss 3.766312, test error 53.15
# Epoch   400, train loss 0.004072, train error 0.00,  test loss 4.037148, test error 53.17
# Epoch   500, train loss 0.002864, train error 0.00,  test loss 4.232874, test error 53.25
# Epoch   600, train loss 0.002178, train error 0.00,  test loss 4.388626, test error 53.20
# Epoch   700, train loss 0.001744, train error 0.00,  test loss 4.514594, test error 53.12
# Epoch   800, train loss 0.001445, train error 0.00,  test loss 4.622076, test error 53.17
# Epoch   900, train loss 0.001228, train error 0.00,  test loss 4.715677, test error 53.20
# Training model with 100 hidden variables
# Epoch     0, train loss 1.982372, train error 74.15,  test loss 1.909783, test error 74.12
# Epoch   100, train loss 0.085176, train error 0.18,  test loss 2.265606, test error 51.17
# Epoch   200, train loss 0.011977, train error 0.00,  test loss 3.098403, test error 51.40
# Epoch   300, train loss 0.005624, train error 0.00,  test loss 3.458577, test error 51.33
# Epoch   400, train loss 0.003525, train error 0.00,  test loss 3.683712, test error 51.40
# Epoch   500, train loss 0.002511, train error 0.00,  test loss 3.851437, test error 51.45
# Epoch   600, train loss 0.001927, train error 0.00,  test loss 3.982983, test error 51.53
# Epoch   700, train loss 0.001549, train error 0.00,  test loss 4.089592, test error 51.55
# Epoch   800, train loss 0.001288, train error 0.00,  test loss 4.180978, test error 51.60
# Epoch   900, train loss 0.001098, train error 0.00,  test loss 4.260815, test error 51.58
# Training model with 120 hidden variables
# Epoch     0, train loss 1.969043, train error 72.25,  test loss 1.894609, test error 72.57
# Epoch   100, train loss 0.051306, train error 0.03,  test loss 2.193178, test error 49.78
# Epoch   200, train loss 0.009409, train error 0.00,  test loss 2.789367, test error 49.30
# Epoch   300, train loss 0.004664, train error 0.00,  test loss 3.064745, test error 49.65
# Epoch   400, train loss 0.002981, train error 0.00,  test loss 3.242528, test error 49.78
# Epoch   500, train loss 0.002149, train error 0.00,  test loss 3.374544, test error 49.72
# Epoch   600, train loss 0.001661, train error 0.00,  test loss 3.476519, test error 49.72
# Epoch   700, train loss 0.001343, train error 0.00,  test loss 3.561800, test error 49.67
# Epoch   800, train loss 0.001121, train error 0.00,  test loss 3.633317, test error 49.60
# Epoch   900, train loss 0.000958, train error 0.00,  test loss 3.696417, test error 49.65
# Training model with 140 hidden variables
# Epoch     0, train loss 1.978237, train error 73.10,  test loss 1.904242, test error 73.32
# Epoch   100, train loss 0.036973, train error 0.00,  test loss 2.228272, test error 49.75
# Epoch   200, train loss 0.008132, train error 0.00,  test loss 2.740873, test error 49.22
# Epoch   300, train loss 0.004141, train error 0.00,  test loss 2.981149, test error 49.33
# Epoch   400, train loss 0.002674, train error 0.00,  test loss 3.137711, test error 49.12
# Epoch   500, train loss 0.001946, train error 0.00,  test loss 3.257522, test error 49.20
# Epoch   600, train loss 0.001512, train error 0.00,  test loss 3.348580, test error 49.28
# Epoch   700, train loss 0.001227, train error 0.00,  test loss 3.426764, test error 49.30
# Epoch   800, train loss 0.001027, train error 0.00,  test loss 3.492841, test error 49.33
# Epoch   900, train loss 0.000880, train error 0.00,  test loss 3.550600, test error 49.20
# Training model with 160 hidden variables
# Epoch     0, train loss 1.930697, train error 70.88,  test loss 1.860887, test error 72.18
# Epoch   100, train loss 0.027568, train error 0.00,  test loss 2.109778, test error 49.55
# Epoch   200, train loss 0.007128, train error 0.00,  test loss 2.501343, test error 49.17
# Epoch   300, train loss 0.003760, train error 0.00,  test loss 2.696938, test error 49.25
# Epoch   400, train loss 0.002482, train error 0.00,  test loss 2.825677, test error 48.97
# Epoch   500, train loss 0.001817, train error 0.00,  test loss 2.922269, test error 48.88
# Epoch   600, train loss 0.001420, train error 0.00,  test loss 2.999235, test error 49.00
# Epoch   700, train loss 0.001157, train error 0.00,  test loss 3.063748, test error 49.15
# Epoch   800, train loss 0.000972, train error 0.00,  test loss 3.118666, test error 49.08
# Epoch   900, train loss 0.000834, train error 0.00,  test loss 3.166800, test error 49.08
# Training model with 180 hidden variables
# Epoch     0, train loss 1.914740, train error 70.25,  test loss 1.865279, test error 72.93
# Epoch   100, train loss 0.024290, train error 0.00,  test loss 2.060222, test error 49.35
# Epoch   200, train loss 0.006570, train error 0.00,  test loss 2.403139, test error 49.33
# Epoch   300, train loss 0.003522, train error 0.00,  test loss 2.577129, test error 49.20
# Epoch   400, train loss 0.002336, train error 0.00,  test loss 2.693961, test error 49.10
# Epoch   500, train loss 0.001720, train error 0.00,  test loss 2.783182, test error 49.17
# Epoch   600, train loss 0.001348, train error 0.00,  test loss 2.853859, test error 49.10
# Epoch   700, train loss 0.001101, train error 0.00,  test loss 2.913881, test error 49.08
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 2.964542, test error 49.00
# Epoch   900, train loss 0.000796, train error 0.00,  test loss 3.009304, test error 48.85
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918491, train error 70.03,  test loss 1.856549, test error 72.25
# Epoch   100, train loss 0.021073, train error 0.00,  test loss 2.051548, test error 48.67
# Epoch   200, train loss 0.006104, train error 0.00,  test loss 2.380431, test error 49.08
# Epoch   300, train loss 0.003322, train error 0.00,  test loss 2.548010, test error 48.97
# Epoch   400, train loss 0.002219, train error 0.00,  test loss 2.659164, test error 48.90
# Epoch   500, train loss 0.001639, train error 0.00,  test loss 2.744604, test error 48.78
# Epoch   600, train loss 0.001287, train error 0.00,  test loss 2.812305, test error 48.83
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.869791, test error 48.85
# Epoch   800, train loss 0.000887, train error 0.00,  test loss 2.918454, test error 48.90
# Epoch   900, train loss 0.000764, train error 0.00,  test loss 2.961289, test error 48.92
# Training model with 250 hidden variables
# Epoch     0, train loss 1.854115, train error 66.25,  test loss 1.796410, test error 70.18
# Epoch   100, train loss 0.016416, train error 0.00,  test loss 2.007876, test error 48.60
# Epoch   200, train loss 0.005229, train error 0.00,  test loss 2.271228, test error 48.17
# Epoch   300, train loss 0.002924, train error 0.00,  test loss 2.411840, test error 47.85
# Epoch   400, train loss 0.001977, train error 0.00,  test loss 2.508551, test error 47.88
# Epoch   500, train loss 0.001473, train error 0.00,  test loss 2.581511, test error 47.92
# Epoch   600, train loss 0.001163, train error 0.00,  test loss 2.639854, test error 47.90
# Epoch   700, train loss 0.000955, train error 0.00,  test loss 2.688794, test error 47.88
# Epoch   800, train loss 0.000807, train error 0.00,  test loss 2.730831, test error 47.90
# Epoch   900, train loss 0.000696, train error 0.00,  test loss 2.768158, test error 47.83
# Training model with 300 hidden variables
# Epoch     0, train loss 1.864281, train error 65.78,  test loss 1.785654, test error 68.40
# Epoch   100, train loss 0.014532, train error 0.00,  test loss 1.830879, test error 46.50
# Epoch   200, train loss 0.004819, train error 0.00,  test loss 2.045632, test error 46.33
# Epoch   300, train loss 0.002722, train error 0.00,  test loss 2.162460, test error 46.38
# Epoch   400, train loss 0.001853, train error 0.00,  test loss 2.241209, test error 46.28
# Epoch   500, train loss 0.001385, train error 0.00,  test loss 2.303267, test error 46.25
# Epoch   600, train loss 0.001097, train error 0.00,  test loss 2.352176, test error 46.28
# Epoch   700, train loss 0.000903, train error 0.00,  test loss 2.393760, test error 46.17
# Epoch   800, train loss 0.000765, train error 0.00,  test loss 2.429626, test error 46.15
# Epoch   900, train loss 0.000661, train error 0.00,  test loss 2.460830, test error 46.05
# Training model with 400 hidden variables
# Epoch     0, train loss 1.834556, train error 65.35,  test loss 1.778857, test error 67.43
# Epoch   100, train loss 0.011698, train error 0.00,  test loss 1.744619, test error 46.65
# Epoch   200, train loss 0.004183, train error 0.00,  test loss 1.914090, test error 46.05
# Epoch   300, train loss 0.002419, train error 0.00,  test loss 2.007761, test error 45.90
# Epoch   400, train loss 0.001665, train error 0.00,  test loss 2.074029, test error 45.95
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.125080, test error 45.80
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.166155, test error 45.80
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.200776, test error 45.67
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.230426, test error 45.75
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.256692, test error 45.62

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
